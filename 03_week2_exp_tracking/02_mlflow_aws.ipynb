# %%
import mlflow

# ran this command
# mlflow ui --backend-store-uri sqlite:///mlflow.db

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("MLOps-Zoomcamp-Homework-2")

# %% [markdown]
# - Once we finish with the experiment tracking stage, we save the model
# - Then we deploy the model
# - After then we can think of updating the model
# - In this tutorial we will look at managing and deployment of models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
